# %% [markdown]
# # Extracting Financial Statements from SEC Filings

# %%
api_key = "a1f46cf5ef92f8f2bc866471e25910cb8bda35a8fb2461398e8bb48af7c9485d"
xbrl_converter_api_endpoint = "https://api.sec-api.io/xbrl-to-json"

# %%
import requests
import json
import pandas as pd
import numpy as np

# %% [markdown]
# # Getting the URLs and Accessing the 10-K Filings:

# %%
filing_10k_url = "https://www.sec.gov/ix?doc=/Archives/edgar/data/0001318605/000095017023001409/tsla-20221231.htm"
api_access_url = xbrl_converter_api_endpoint + "?htm-url=" + filing_10k_url + "&token=" + api_key

# %%
response = requests.get(api_access_url)
filing_json = json.loads(response.text)

# %% [markdown]
# ## Getting Income Statement from Filing:

# %%
print(filing_json['StatementsOfIncome'])
# Out:
# {'EarningsPerShareBasic': [{'decimals': '2', 'unitRef': 'U_USDollarShare', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'value': '4.02'}, {'decimals': '2', 'unitRef': 'U_USDollarShare', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'value': '1.87'}, {'decimals': '2', 'unitRef': 'U_USDollarShare', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'value': '0.25'}], 'WeightedAverageNumberOfSharesOutstandingBasic': [{'decimals': '-6', 'unitRef': 'U_shares', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'value': '3130000000'}, {'decimals': '-6', 'unitRef': 'U_shares', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'value': '2959000000'}, {'decimals': '-6', 'unitRef': 'U_shares', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'value': '2798000000'}], 'ResearchAndDevelopmentExpense': [{'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'value': '3075000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'value': '2593000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'value': '1491000000'}], 'AutomotiveSalesRevenue': [{'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'segment': {'dimension': 'srt:ProductOrServiceAxis', 'value': 'tsla:AutomotiveRevenuesMember'}, 'value': '67210000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'segment': {'dimension': 'srt:ProductOrServiceAxis', 'value': 'tsla:AutomotiveRevenuesMember'}, 'value': '44125000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'segment': {'dimension': 'srt:ProductOrServiceAxis', 'value': 'tsla:AutomotiveRevenuesMember'}, 'value': '24604000000'}], 'AutomotiveSales': [{'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'segment': {'dimension': 'srt:ProductOrServiceAxis', 'value': 'tsla:AutomotiveRevenuesMember'}, 'value': '49599000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'segment': {'dimension': 'srt:ProductOrServiceAxis', 'value': 'tsla:AutomotiveRevenuesMember'}, 'value': '32415000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'segment': {'dimension': 'srt:ProductOrServiceAxis', 'value': 'tsla:AutomotiveRevenuesMember'}, 'value': '19696000000'}], 'EarningsPerShareDiluted': [{'decimals': '2', 'unitRef': 'U_USDollarShare', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'value': '3.62'}, {'decimals': '2', 'unitRef': 'U_USDollarShare', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'value': '1.63'}, {'decimals': '2', 'unitRef': 'U_USDollarShare', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'value': '0.21'}], 'WeightedAverageNumberOfDilutedSharesOutstanding': [{'decimals': '-6', 'unitRef': 'U_shares', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'value': '3475000000'}, {'decimals': '-6', 'unitRef': 'U_shares', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'value': '3386000000'}, {'decimals': '-6', 'unitRef': 'U_shares', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'value': '3249000000'}], 'SellingGeneralAndAdministrativeExpense': [{'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'}, 'value': '3946000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'}, 'value': '4517000000'}, {'decimals': '-6', 'unitRef': 'U_USD', 'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'}, 'value': '3145000000'}], 'AutomotiveRegulatoryCredits': [{'decimals':  ...

# %%
income_state_json = filing_json['StatementsOfIncome']

# %% [markdown]
# ## Convert the Income Statement into a Data Frame

# %%
def transform_income_statement(statement_json):
    store_income_statement= {}

    # iterate over each US GAAP item in the income statement
    for item in statement_json:
        values = []
        indicies = []
        for fact in income_state_json[item]:
            
            # only consider items without segment. not required for our analysis.
            if 'segment' not in fact:
                index = fact['period']['startDate'] + '-' + fact['period']['endDate']
                # ensure no index duplicates are created
                if index not in indicies:
                    values.append(fact['value'])
                    indicies.append(index)                    

            store_income_statement[item] = pd.Series(values, index=indicies, dtype = 'float64') 

        income_statement = pd.DataFrame(store_income_statement)
    
    
    # Transposing DF so that items are rows and individual column headers represent a date range
    return income_statement.T

# %%
income_statement = transform_income_statement(income_state_json)

# %%
income_statement = income_statement.replace(np.nan,0)
income_statement = income_statement.style.format("{:.1f}")

# %% [markdown]
# # View Income Statement as a DataFrame

# %%
income_statement
# Out:
# <style type="text/css">
# </style>
# <table id="T_f56cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f56cd_level0_col0" class="col_heading level0 col0" >2020-01-01-2020-12-31</th>
#       <th id="T_f56cd_level0_col1" class="col_heading level0 col1" >2021-01-01-2021-12-31</th>
#       <th id="T_f56cd_level0_col2" class="col_heading level0 col2" >2022-01-01-2022-12-31</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f56cd_level0_row0" class="row_heading level0 row0" >EarningsPerShareBasic</th>
#       <td id="T_f56cd_row0_col0" class="data row0 col0" >0.2</td>
#       <td id="T_f56cd_row0_col1" class="data row0 col1" >1.9</td>
#       <td id="T_f56cd_row0_col2" class="data row0 col2" >4.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row1" class="row_heading level0 row1" >WeightedAverageNumberOfSharesOutstandingBasic</th>
#       <td id="T_f56cd_row1_col0" class="data row1 col0" >2798000000.0</td>
#       <td id="T_f56cd_row1_col1" class="data row1 col1" >2959000000.0</td>
#       <td id="T_f56cd_row1_col2" class="data row1 col2" >3130000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row2" class="row_heading level0 row2" >ResearchAndDevelopmentExpense</th>
#       <td id="T_f56cd_row2_col0" class="data row2 col0" >1491000000.0</td>
#       <td id="T_f56cd_row2_col1" class="data row2 col1" >2593000000.0</td>
#       <td id="T_f56cd_row2_col2" class="data row2 col2" >3075000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row3" class="row_heading level0 row3" >AutomotiveSalesRevenue</th>
#       <td id="T_f56cd_row3_col0" class="data row3 col0" >0.0</td>
#       <td id="T_f56cd_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_f56cd_row3_col2" class="data row3 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row4" class="row_heading level0 row4" >AutomotiveSales</th>
#       <td id="T_f56cd_row4_col0" class="data row4 col0" >0.0</td>
#       <td id="T_f56cd_row4_col1" class="data row4 col1" >0.0</td>
#       <td id="T_f56cd_row4_col2" class="data row4 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row5" class="row_heading level0 row5" >EarningsPerShareDiluted</th>
#       <td id="T_f56cd_row5_col0" class="data row5 col0" >0.2</td>
#       <td id="T_f56cd_row5_col1" class="data row5 col1" >1.6</td>
#       <td id="T_f56cd_row5_col2" class="data row5 col2" >3.6</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row6" class="row_heading level0 row6" >WeightedAverageNumberOfDilutedSharesOutstanding</th>
#       <td id="T_f56cd_row6_col0" class="data row6 col0" >3249000000.0</td>
#       <td id="T_f56cd_row6_col1" class="data row6 col1" >3386000000.0</td>
#       <td id="T_f56cd_row6_col2" class="data row6 col2" >3475000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row7" class="row_heading level0 row7" >SellingGeneralAndAdministrativeExpense</th>
#       <td id="T_f56cd_row7_col0" class="data row7 col0" >3145000000.0</td>
#       <td id="T_f56cd_row7_col1" class="data row7 col1" >4517000000.0</td>
#       <td id="T_f56cd_row7_col2" class="data row7 col2" >3946000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row8" class="row_heading level0 row8" >AutomotiveRegulatoryCredits</th>
#       <td id="T_f56cd_row8_col0" class="data row8 col0" >0.0</td>
#       <td id="T_f56cd_row8_col1" class="data row8 col1" >0.0</td>
#       <td id="T_f56cd_row8_col2" class="data row8 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row9" class="row_heading level0 row9" >DirectCostsOfLeasedAndRentedPropertyOrEquipment</th>
#       <td id="T_f56cd_row9_col0" class="data row9 col0" >0.0</td>
#       <td id="T_f56cd_row9_col1" class="data row9 col1" >0.0</td>
#       <td id="T_f56cd_row9_col2" class="data row9 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row10" class="row_heading level0 row10" >RestructuringAndOtherExpenses</th>
#       <td id="T_f56cd_row10_col0" class="data row10 col0" >0.0</td>
#       <td id="T_f56cd_row10_col1" class="data row10 col1" >-27000000.0</td>
#       <td id="T_f56cd_row10_col2" class="data row10 col2" >176000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row11" class="row_heading level0 row11" >GrossProfit</th>
#       <td id="T_f56cd_row11_col0" class="data row11 col0" >6630000000.0</td>
#       <td id="T_f56cd_row11_col1" class="data row11 col1" >13606000000.0</td>
#       <td id="T_f56cd_row11_col2" class="data row11 col2" >20853000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row12" class="row_heading level0 row12" >AutomotiveLeasing</th>
#       <td id="T_f56cd_row12_col0" class="data row12 col0" >0.0</td>
#       <td id="T_f56cd_row12_col1" class="data row12 col1" >0.0</td>
#       <td id="T_f56cd_row12_col2" class="data row12 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row13" class="row_heading level0 row13" >AutomotiveCostOfRevenues</th>
#       <td id="T_f56cd_row13_col0" class="data row13 col0" >0.0</td>
#       <td id="T_f56cd_row13_col1" class="data row13 col1" >0.0</td>
#       <td id="T_f56cd_row13_col2" class="data row13 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row14" class="row_heading level0 row14" >OperatingExpenses</th>
#       <td id="T_f56cd_row14_col0" class="data row14 col0" >4636000000.0</td>
#       <td id="T_f56cd_row14_col1" class="data row14 col1" >7083000000.0</td>
#       <td id="T_f56cd_row14_col2" class="data row14 col2" >7197000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row15" class="row_heading level0 row15" >AutomotiveRevenues</th>
#       <td id="T_f56cd_row15_col0" class="data row15 col0" >0.0</td>
#       <td id="T_f56cd_row15_col1" class="data row15 col1" >0.0</td>
#       <td id="T_f56cd_row15_col2" class="data row15 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row16" class="row_heading level0 row16" >CostOfGoodsAndServicesSold</th>
#       <td id="T_f56cd_row16_col0" class="data row16 col0" >0.0</td>
#       <td id="T_f56cd_row16_col1" class="data row16 col1" >0.0</td>
#       <td id="T_f56cd_row16_col2" class="data row16 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row17" class="row_heading level0 row17" >OperatingIncomeLoss</th>
#       <td id="T_f56cd_row17_col0" class="data row17 col0" >1994000000.0</td>
#       <td id="T_f56cd_row17_col1" class="data row17 col1" >6523000000.0</td>
#       <td id="T_f56cd_row17_col2" class="data row17 col2" >13656000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row18" class="row_heading level0 row18" >RevenueFromContractWithCustomerExcludingAssessedTax</th>
#       <td id="T_f56cd_row18_col0" class="data row18 col0" >0.0</td>
#       <td id="T_f56cd_row18_col1" class="data row18 col1" >0.0</td>
#       <td id="T_f56cd_row18_col2" class="data row18 col2" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row19" class="row_heading level0 row19" >CostOfRevenue</th>
#       <td id="T_f56cd_row19_col0" class="data row19 col0" >24906000000.0</td>
#       <td id="T_f56cd_row19_col1" class="data row19 col1" >40217000000.0</td>
#       <td id="T_f56cd_row19_col2" class="data row19 col2" >60609000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row20" class="row_heading level0 row20" >InvestmentIncomeInterest</th>
#       <td id="T_f56cd_row20_col0" class="data row20 col0" >30000000.0</td>
#       <td id="T_f56cd_row20_col1" class="data row20 col1" >56000000.0</td>
#       <td id="T_f56cd_row20_col2" class="data row20 col2" >297000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row21" class="row_heading level0 row21" >Revenues</th>
#       <td id="T_f56cd_row21_col0" class="data row21 col0" >31536000000.0</td>
#       <td id="T_f56cd_row21_col1" class="data row21 col1" >53823000000.0</td>
#       <td id="T_f56cd_row21_col2" class="data row21 col2" >81462000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_f56cd_level0_row22" class="row_heading level0 row22" >InterestExpense</th>
#       <td id="T_f56cd_row22_col0" class="data row22 col0" >748000000.0</td>
#       <td id="T_f56cd_row22_col1

# %% [markdown]
# ## Get Balance Sheet from URL

# %%
balance_sheet_json = filing_json['BalanceSheets']

# %% [markdown]
# ## Convert the Balance Sheet into a Data Frame

# %%
def transform_balance_sheet(statement_json):
    store_balance_sheet = {}

    # iterate over each US GAAP item in the income statement
    for item in statement_json:
        values = []
        indicies = []
        for fact in statement_json[item]:
            
            # only consider items without segment. not required for our analysis.
            if 'segment' not in fact:
                index =  fact['period']['instant']
                # ensure no index duplicates are created
                if index in indicies:
                    continue
                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])
                    
                indicies.append(index)                    

            store_balance_sheet[item] = pd.Series(values, index=indicies, dtype = 'float64') 

        balance_sheet = pd.DataFrame(store_balance_sheet)
    
    
    # Transposing DF so that items are rows and individual column headers represent a date range
    return balance_sheet.T

# %%
balance_sheet = transform_balance_sheet(balance_sheet_json)
balance_sheet = balance_sheet.replace(np.nan,0)
balance_sheet = balance_sheet.style.format("{:.1f}")

# %% [markdown]
# # View Balance Sheet as Data Frame

# %%
balance_sheet
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b74c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b74c_level0_col0" class="col_heading level0 col0" >2020-12-31</th>
#       <th id="T_4b74c_level0_col1" class="col_heading level0 col1" >2021-01-01</th>
#       <th id="T_4b74c_level0_col2" class="col_heading level0 col2" >2021-12-31</th>
#       <th id="T_4b74c_level0_col3" class="col_heading level0 col3" >2022-12-31</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b74c_level0_row0" class="row_heading level0 row0" >PreferredStockValue</th>
#       <td id="T_4b74c_row0_col0" class="data row0 col0" >0.0</td>
#       <td id="T_4b74c_row0_col1" class="data row0 col1" >0.0</td>
#       <td id="T_4b74c_row0_col2" class="data row0 col2" >0.0</td>
#       <td id="T_4b74c_row0_col3" class="data row0 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row1" class="row_heading level0 row1" >CashAndCashEquivalentsAtCarryingValue</th>
#       <td id="T_4b74c_row1_col0" class="data row1 col0" >19384000000.0</td>
#       <td id="T_4b74c_row1_col1" class="data row1 col1" >0.0</td>
#       <td id="T_4b74c_row1_col2" class="data row1 col2" >17576000000.0</td>
#       <td id="T_4b74c_row1_col3" class="data row1 col3" >16253000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row2" class="row_heading level0 row2" >AccountsPayableCurrent</th>
#       <td id="T_4b74c_row2_col0" class="data row2 col0" >0.0</td>
#       <td id="T_4b74c_row2_col1" class="data row2 col1" >0.0</td>
#       <td id="T_4b74c_row2_col2" class="data row2 col2" >10025000000.0</td>
#       <td id="T_4b74c_row2_col3" class="data row2 col3" >15255000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row3" class="row_heading level0 row3" >MinorityInterest</th>
#       <td id="T_4b74c_row3_col0" class="data row3 col0" >0.0</td>
#       <td id="T_4b74c_row3_col1" class="data row3 col1" >0.0</td>
#       <td id="T_4b74c_row3_col2" class="data row3 col2" >826000000.0</td>
#       <td id="T_4b74c_row3_col3" class="data row3 col3" >785000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row4" class="row_heading level0 row4" >LongTermDebtAndFinanceLeasesNoncurrent</th>
#       <td id="T_4b74c_row4_col0" class="data row4 col0" >9556000000.0</td>
#       <td id="T_4b74c_row4_col1" class="data row4 col1" >9775000000.0</td>
#       <td id="T_4b74c_row4_col2" class="data row4 col2" >5245000000.0</td>
#       <td id="T_4b74c_row4_col3" class="data row4 col3" >1597000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row5" class="row_heading level0 row5" >CommonStockValue</th>
#       <td id="T_4b74c_row5_col0" class="data row5 col0" >0.0</td>
#       <td id="T_4b74c_row5_col1" class="data row5 col1" >0.0</td>
#       <td id="T_4b74c_row5_col2" class="data row5 col2" >3000000.0</td>
#       <td id="T_4b74c_row5_col3" class="data row5 col3" >3000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row6" class="row_heading level0 row6" >DeferredCostsLeasingNetNoncurrent</th>
#       <td id="T_4b74c_row6_col0" class="data row6 col0" >0.0</td>
#       <td id="T_4b74c_row6_col1" class="data row6 col1" >0.0</td>
#       <td id="T_4b74c_row6_col2" class="data row6 col2" >0.0</td>
#       <td id="T_4b74c_row6_col3" class="data row6 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row7" class="row_heading level0 row7" >ShortTermInvestments</th>
#       <td id="T_4b74c_row7_col0" class="data row7 col0" >0.0</td>
#       <td id="T_4b74c_row7_col1" class="data row7 col1" >0.0</td>
#       <td id="T_4b74c_row7_col2" class="data row7 col2" >131000000.0</td>
#       <td id="T_4b74c_row7_col3" class="data row7 col3" >5932000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row8" class="row_heading level0 row8" >AccruedAndOtherCurrentLiabilities</th>
#       <td id="T_4b74c_row8_col0" class="data row8 col0" >0.0</td>
#       <td id="T_4b74c_row8_col1" class="data row8 col1" >0.0</td>
#       <td id="T_4b74c_row8_col2" class="data row8 col2" >5719000000.0</td>
#       <td id="T_4b74c_row8_col3" class="data row8 col3" >7142000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row9" class="row_heading level0 row9" >CommitmentsAndContingencies</th>
#       <td id="T_4b74c_row9_col0" class="data row9 col0" >0.0</td>
#       <td id="T_4b74c_row9_col1" class="data row9 col1" >0.0</td>
#       <td id="T_4b74c_row9_col2" class="data row9 col2" >0.0</td>
#       <td id="T_4b74c_row9_col3" class="data row9 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row10" class="row_heading level0 row10" >ContractWithCustomerLiabilityNoncurrent</th>
#       <td id="T_4b74c_row10_col0" class="data row10 col0" >0.0</td>
#       <td id="T_4b74c_row10_col1" class="data row10 col1" >0.0</td>
#       <td id="T_4b74c_row10_col2" class="data row10 col2" >2052000000.0</td>
#       <td id="T_4b74c_row10_col3" class="data row10 col3" >2804000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row11" class="row_heading level0 row11" >AdditionalPaidInCapitalCommonStock</th>
#       <td id="T_4b74c_row11_col0" class="data row11 col0" >0.0</td>
#       <td id="T_4b74c_row11_col1" class="data row11 col1" >0.0</td>
#       <td id="T_4b74c_row11_col2" class="data row11 col2" >29803000000.0</td>
#       <td id="T_4b74c_row11_col3" class="data row11 col3" >32177000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row12" class="row_heading level0 row12" >LeasedAssetsNet</th>
#       <td id="T_4b74c_row12_col0" class="data row12 col0" >0.0</td>
#       <td id="T_4b74c_row12_col1" class="data row12 col1" >0.0</td>
#       <td id="T_4b74c_row12_col2" class="data row12 col2" >0.0</td>
#       <td id="T_4b74c_row12_col3" class="data row12 col3" >0.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row13" class="row_heading level0 row13" >AccountsReceivableNetCurrent</th>
#       <td id="T_4b74c_row13_col0" class="data row13 col0" >0.0</td>
#       <td id="T_4b74c_row13_col1" class="data row13 col1" >0.0</td>
#       <td id="T_4b74c_row13_col2" class="data row13 col2" >1913000000.0</td>
#       <td id="T_4b74c_row13_col3" class="data row13 col3" >2952000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row14" class="row_heading level0 row14" >ContractWithCustomerLiabilityCurrent</th>
#       <td id="T_4b74c_row14_col0" class="data row14 col0" >0.0</td>
#       <td id="T_4b74c_row14_col1" class="data row14 col1" >0.0</td>
#       <td id="T_4b74c_row14_col2" class="data row14 col2" >1447000000.0</td>
#       <td id="T_4b74c_row14_col3" class="data row14 col3" >1747000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row15" class="row_heading level0 row15" >RedeemableNoncontrollingInterestEquityCarryingAmount</th>
#       <td id="T_4b74c_row15_col0" class="data row15 col0" >0.0</td>
#       <td id="T_4b74c_row15_col1" class="data row15 col1" >0.0</td>
#       <td id="T_4b74c_row15_col2" class="data row15 col2" >568000000.0</td>
#       <td id="T_4b74c_row15_col3" class="data row15 col3" >409000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row16" class="row_heading level0 row16" >OtherLiabilitiesNoncurrent</th>
#       <td id="T_4b74c_row16_col0" class="data row16 col0" >0.0</td>
#       <td id="T_4b74c_row16_col1" class="data row16 col1" >0.0</td>
#       <td id="T_4b74c_row16_col2" class="data row16 col2" >3546000000.0</td>
#       <td id="T_4b74c_row16_col3" class="data row16 col3" >5330000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row17" class="row_heading level0 row17" >AccumulatedOtherComprehensiveIncomeLossNetOfTax</th>
#       <td id="T_4b74c_row17_col0" class="data row17 col0" >0.0</td>
#       <td id="T_4b74c_row17_col1" class="data row17 col1" >0.0</td>
#       <td id="T_4b74c_row17_col2" class="data row17 col2" >54000000.0</td>
#       <td id="T_4b74c_row17_col3" class="data row17 col3" >-361000000.0</td>
#     </tr>
#     <tr>
#       <th id="T_4b74c_level0_row18" class="row_heading level0 row18" >PropertyPlantAndEquipmentNet</th>
#       <td id="T_4b74c_row18_col0" class="data row18 col0" >12747000000.0</td>
#       <t

# %% [markdown]
# ## Get Cash Flow Statement from API

# %%
cash_flow_json = filing_json["StatementsOfCashFlows"]
cash_flow_json
# Out:
# {'ProceedsFromIssuanceOfCommonStock': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '12269000000'}],
#  'InterestPaidNet': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '152000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '266000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '444000000'}],
#  'ProfitLoss': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '12587000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '5644000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '862000000'}],
#  'PaymentsToAcquirePropertyPlantAndEquipment': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '7158000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '6482000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '3157000000'}],
#  'DepreciationAmortizationAndImpairment': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '3747000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '2911000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '2322000000'}],
#  'IncreaseDecreaseInAccountsReceivable': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '1124000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '130000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '652000000'}],
#  'NoncashOrPartNoncashAcquisitionValueOfAssetsAcquired1': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '2148000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '2251000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '1088000000'}],
#  'ProceedsFromIssuanceOfDebt': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '8883000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '9713000000'}],
#  'IncomeTaxesPaid': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '1203000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '561000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '115000000'}],
#  'PaymentsForSolarEnergySystemsNetOfSales': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '5000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '32000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '75000000'}],
#  'ShareBasedCompensation': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '1560000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '2121000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '1734000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'segment': [{'dimension': 'srt:TitleOfIndividualAxis',
#      'value': 'srt:ChiefExecutiveOfficerMember'},
#     {'dimension': 'us-gaap:AwardTypeAxis',
#      'value': 'tsla:TwoThousandAndEighteenPerformanceAwardMember'}],
#    'value': '66000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'segment': [{'dimension': 'srt:TitleOfIndividualAxis',
#      'value': 'srt:ChiefExecutiveOfficerMember'},
#     {'dimension': 'us-gaap:AwardTypeAxis',
#      'value': 'tsla:TwoThousandAndEighteenPerformanceAwardMember'}],
#    'value': '910000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'segment': [{'dimension': 'srt:TitleOfIndividualAxis',
#      'value': 'srt:ChiefExecutiveOfficerMember'},
#     {'dimension': 'us-gaap:AwardTypeAxis',
#      'value': 'tsla:TwoThousandAndEighteenPerformanceAwardMember'}],
#    'value': '838000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'segment': {'dimension': 'us-gaap:AwardTypeAxis',
#     'value': 'tsla:PerformanceBasedStockOptionMember'},
#    'value': '159000000'}],
#  'IncreaseDecreaseInInventories': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '6465000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '1709000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '422000000'}],
#  'RepaymentsOfConvertibleAndOtherDebt': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '3364000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '14167000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '11623000000'}],
#  'NetCashProvidedByUsedInOperatingActivities': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '14724000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '11497000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '5943000000'}],
#  'PurchaseOfDigitalAssets': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '1500000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '0'}],
#  'InventoryWriteDown': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '177000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '140000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '202000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'segment': {'dimension': 'us-gaap:IncomeStatementLocationAxis',
#     'value': 'us-gaap:CostOfSalesMember'},
#    'value': '144000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'segment': {'dimension': 'us-gaap:IncomeStatementLocationAxis',
#     'value': 'us-gaap:CostOfSalesMember'},
#    'value': '106000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'segment': {'dimension': 'us-gaap:IncomeStatementLocationAxis',
#     'value': 'us-gaap:CostOfSalesMember'},
#    'value': '145000000'}],
#  'IncreaseDecreaseInOperatingLeaseVehicles': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '1570000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '2114000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '1072000000'}],
#  'ProceedsFromRepaymentsOfSecuredDebt': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '-9000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '-240000000'}],
#  'EffectOfExchangeRateOnCashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '-444000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '-183000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '334000000'}],
#  'ProceedsFromSalesOfDigitalAssets': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '936000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '272000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '0'}],
#  'ForeignCurrencyTransactionGainLossUnrealized': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '-81000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '55000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '-114000000'}],
#  'IncreaseDecreaseInPrepaidDeferredExpenseAndOtherAssets': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '1417000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '271000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '251000000'}],
#  'ProceedsFromIssuanceOfSharesUnderIncentiveAndShareBasedCompensationPlansIncludingStockOptions': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '541000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '707000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '417000000'}],
#  'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsPeriodIncreaseDecreaseIncludingExchangeRateEffect': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '-1220000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '-1757000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '13118000000'}],
#  'PaymentsToAcquireOtherIndefiniteLivedIntangibleAssets': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '9000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '10000000'}],
#  'NoncashInterestIncomeExpenseAndOtherOperatingActivities': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '-340000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '-245000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '-525000000'}],
#  'IncreaseDecreaseInOtherNoncurrentAssets': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '2551000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '1291000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '344000000'}],
#  'FinanceLeasePrincipalPayments': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '502000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '439000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '338000000'}],
#  'CashCashEquivalentsRestrictedCashAndRestrictedCashEquivalentsIncludingDisposalGroupAndDiscontinuedOperations': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'instant': '2021-12-31'},
#    'value': '18144000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'instant': '2020-12-31'},
#    'value': '19901000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'instant': '2019-12-31'},
#    'value': '6783000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'instant': '2022-12-31'},
#    'value': '16924000000'}],
#  'PaymentsToAcquireInvestments': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '5835000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '132000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '0'}],
#  'GainLossOnDigitalAssets': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '-140000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '27000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '0'}],
#  'IncreaseDecreaseInAccountsPayableAndAccruedLiabilities': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '6029000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '4578000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '2102000000'}],
#  'PaymentsOfDebtIssuanceCosts': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '9000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '6000000'}],
#  'ProceedsFromSaleMaturityAndCollectionsOfInvestments': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '22000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '0'}],
#  'IncreaseDecreaseInContractWithCustomerLiability': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '1131000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '793000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '321000000'}],
#  'ProceedsFromMinorityShareholders': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '2000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '24000000'}],
#  'GovernmentGrantReceipt': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '76000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '6000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '123000000'}],
#  'IncreaseDecreaseInContractWithCustomerLiabilityCustomerDeposits': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '155000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '186000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '7000000'}],
#  'PaymentsToMinorityShareholders': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '157000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '161000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '208000000'}],
#  'PaymentsToAcquireBusinessesNetOfCashAcquired': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '0'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '13000000'}],
#  'IncreaseDecreaseInOtherNoncurrentLiabilities': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '1904000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '476000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '495000000'}],
#  'PaymentsForBuyOutsOfNoncontrollingInterestsInSubsidiaries': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '45000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '10000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '35000000'}],
#  'NetCashProvidedByUsedInInvestingActivities': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '-11973000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '-7868000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '-3132000000'}],
#  'NetCashProvidedByUsedInFinancingActivities': [{'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2022-01-01', 'endDate': '2022-12-31'},
#    'value': '-3527000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2021-01-01', 'endDate': '2021-12-31'},
#    'value': '-5203000000'},
#   {'decimals': '-6',
#    'unitRef': 'U_USD',
#    'period': {'startDate': '2020-01-01', 'endDate': '2020-12-31'},
#    'value': '9973000000'}]}

# %%
def transform_cash_flow_statement(statement_json):
    store_cash_flows = {}

    for item in statement_json:
        values = []
        indicies = []

        for fact in statement_json[item]:        
            # only consider items without segment.
            if 'segment' not in fact:
                # check if date instant or date range is present
                if "instant" in fact['period']:
                    index = fact['period']['instant']
                else:
                    index = fact['period']['startDate'] + '-' + fact['period']['endDate']

                # avoid duplicate indicies with same values
                if index in indicies:
                    continue
                if "value" not in fact:
                    values.append(0)
                else:
                    values.append(fact['value'])

                indicies.append(index)                    

        store_cash_flows[item] = pd.Series(values, index=indicies) 


    cash_flows = pd.DataFrame(store_cash_flows)
    return cash_flows.T

# %%
cash_flow_statement = transform_cash_flow_statement(cash_flow_json)
cash_flow_statement = cash_flow_statement.replace(np.nan,0)
# cash_flow_statement = cash_flow_statement.style.format("{:.1f}")

# %%
cash_flow_statement
# Out:
#                                                     2019-12-31  \
# ProceedsFromIssuanceOfCommonStock                            0
# InterestPaidNet                                              0
# ProfitLoss                                                   0
# PaymentsToAcquirePropertyPlantAndEquipment                   0
# DepreciationAmortizationAndImpairment                        0
# IncreaseDecreaseInAccountsReceivable                         0
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcq...           0
# ProceedsFromIssuanceOfDebt                                   0
# IncomeTaxesPaid                                              0
# PaymentsForSolarEnergySystemsNetOfSales                      0
# ShareBasedCompensation                                       0
# IncreaseDecreaseInInventories                                0
# RepaymentsOfConvertibleAndOtherDebt                          0
# NetCashProvidedByUsedInOperatingActivities                   0
# PurchaseOfDigitalAssets                                      0
# InventoryWriteDown                                           0
# IncreaseDecreaseInOperatingLeaseVehicles                     0
# ProceedsFromRepaymentsOfSecuredDebt                          0
# EffectOfExchangeRateOnCashCashEquivalentsRestri...           0
# ProceedsFromSalesOfDigitalAssets                             0
# ForeignCurrencyTransactionGainLossUnrealized                 0
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...           0
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...           0
# CashCashEquivalentsRestrictedCashAndRestrictedC...           0
# PaymentsToAcquireOtherIndefiniteLivedIntangible...           0
# NoncashInterestIncomeExpenseAndOtherOperatingAc...           0
# IncreaseDecreaseInOtherNoncurrentAssets                      0
# FinanceLeasePrincipalPayments                                0
# CashCashEquivalentsRestrictedCashAndRestrictedC...  6783000000
# PaymentsToAcquireInvestments                                 0
# GainLossOnDigitalAssets                                      0
# IncreaseDecreaseInAccountsPayableAndAccruedLiab...           0
# PaymentsOfDebtIssuanceCosts                                  0
# ProceedsFromSaleMaturityAndCollectionsOfInvestm...           0
# IncreaseDecreaseInContractWithCustomerLiability              0
# ProceedsFromMinorityShareholders                             0
# GovernmentGrantReceipt                                       0
# IncreaseDecreaseInContractWithCustomerLiability...           0
# PaymentsToMinorityShareholders                               0
# PaymentsToAcquireBusinessesNetOfCashAcquired                 0
# IncreaseDecreaseInOtherNoncurrentLiabilities                 0
# PaymentsForBuyOutsOfNoncontrollingInterestsInSu...           0
# NetCashProvidedByUsedInInvestingActivities                   0
# NetCashProvidedByUsedInFinancingActivities                   0
#
#                                                    2020-01-01-2020-12-31  \
# ProceedsFromIssuanceOfCommonStock                            12269000000
# InterestPaidNet                                                444000000
# ProfitLoss                                                     862000000
# PaymentsToAcquirePropertyPlantAndEquipment                    3157000000
# DepreciationAmortizationAndImpairment                         2322000000
# IncreaseDecreaseInAccountsReceivable                           652000000
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcq...            1088000000
# ProceedsFromIssuanceOfDebt                                    9713000000
# IncomeTaxesPaid                                                115000000
# PaymentsForSolarEnergySystemsNetOfSales                         75000000
# ShareBasedCompensation                                        1734000000
# IncreaseDecreaseInInventories                                  422000000
# RepaymentsOfConvertibleAndOtherDebt                          11623000000
# NetCashProvidedByUsedInOperatingActivities                    5943000000
# PurchaseOfDigitalAssets                                                0
# InventoryWriteDown                                             202000000
# IncreaseDecreaseInOperatingLeaseVehicles                      1072000000
# ProceedsFromRepaymentsOfSecuredDebt                           -240000000
# EffectOfExchangeRateOnCashCashEquivalentsRestri...             334000000
# ProceedsFromSalesOfDigitalAssets                                       0
# ForeignCurrencyTransactionGainLossUnrealized                  -114000000
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...             251000000
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...             417000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...           13118000000
# PaymentsToAcquireOtherIndefiniteLivedIntangible...              10000000
# NoncashInterestIncomeExpenseAndOtherOperatingAc...            -525000000
# IncreaseDecreaseInOtherNoncurrentAssets                        344000000
# FinanceLeasePrincipalPayments                                  338000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...                     0
# PaymentsToAcquireInvestments                                           0
# GainLossOnDigitalAssets                                                0
# IncreaseDecreaseInAccountsPayableAndAccruedLiab...            2102000000
# PaymentsOfDebtIssuanceCosts                                      6000000
# ProceedsFromSaleMaturityAndCollectionsOfInvestm...                     0
# IncreaseDecreaseInContractWithCustomerLiability                321000000
# ProceedsFromMinorityShareholders                                24000000
# GovernmentGrantReceipt                                         123000000
# IncreaseDecreaseInContractWithCustomerLiability...               7000000
# PaymentsToMinorityShareholders                                 208000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                    13000000
# IncreaseDecreaseInOtherNoncurrentLiabilities                   495000000
# PaymentsForBuyOutsOfNoncontrollingInterestsInSu...              35000000
# NetCashProvidedByUsedInInvestingActivities                   -3132000000
# NetCashProvidedByUsedInFinancingActivities                    9973000000
#
#                                                      2020-12-31  \
# ProceedsFromIssuanceOfCommonStock                             0
# InterestPaidNet                                               0
# ProfitLoss                                                    0
# PaymentsToAcquirePropertyPlantAndEquipment                    0
# DepreciationAmortizationAndImpairment                         0
# IncreaseDecreaseInAccountsReceivable                          0
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcq...            0
# ProceedsFromIssuanceOfDebt                                    0
# IncomeTaxesPaid                                               0
# PaymentsForSolarEnergySystemsNetOfSales                       0
# ShareBasedCompensation                                        0
# IncreaseDecreaseInInventories                                 0
# RepaymentsOfConvertibleAndOtherDebt                           0
# NetCashProvidedByUsedInOperatingActivities                    0
# PurchaseOfDigitalAssets                                       0
# InventoryWriteDown                                            0
# IncreaseDecreaseInOperatingLeaseVehicles                      0
# ProceedsFromRepaymentsOfSecuredDebt                           0
# EffectOfExchangeRateOnCashCashEquivalentsRestri...            0
# ProceedsFromSalesOfDigitalAssets                              0
# ForeignCurrencyTransactionGainLossUnrealized                  0
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...            0
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...            0
# CashCashEquivalentsRestrictedCashAndRestrictedC...            0
# PaymentsToAcquireOtherIndefiniteLivedIntangible...            0
# NoncashInterestIncomeExpenseAndOtherOperatingAc...            0
# IncreaseDecreaseInOtherNoncurrentAssets                       0
# FinanceLeasePrincipalPayments                                 0
# CashCashEquivalentsRestrictedCashAndRestrictedC...  19901000000
# PaymentsToAcquireInvestments                                  0
# GainLossOnDigitalAssets                                       0
# IncreaseDecreaseInAccountsPayableAndAccruedLiab...            0
# PaymentsOfDebtIssuanceCosts                                   0
# ProceedsFromSaleMaturityAndCollectionsOfInvestm...            0
# IncreaseDecreaseInContractWithCustomerLiability               0
# ProceedsFromMinorityShareholders                              0
# GovernmentGrantReceipt                                        0
# IncreaseDecreaseInContractWithCustomerLiability...            0
# PaymentsToMinorityShareholders                                0
# PaymentsToAcquireBusinessesNetOfCashAcquired                  0
# IncreaseDecreaseInOtherNoncurrentLiabilities                  0
# PaymentsForBuyOutsOfNoncontrollingInterestsInSu...            0
# NetCashProvidedByUsedInInvestingActivities                    0
# NetCashProvidedByUsedInFinancingActivities                    0
#
#                                                    2021-01-01-2021-12-31  \
# ProceedsFromIssuanceOfCommonStock                                      0
# InterestPaidNet                                                266000000
# ProfitLoss                                                    5644000000
# PaymentsToAcquirePropertyPlantAndEquipment                    6482000000
# DepreciationAmortizationAndImpairment                         2911000000
# IncreaseDecreaseInAccountsReceivable                           130000000
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcq...            2251000000
# ProceedsFromIssuanceOfDebt                                    8883000000
# IncomeTaxesPaid                                                561000000
# PaymentsForSolarEnergySystemsNetOfSales                         32000000
# ShareBasedCompensation                                        2121000000
# IncreaseDecreaseInInventories                                 1709000000
# RepaymentsOfConvertibleAndOtherDebt                          14167000000
# NetCashProvidedByUsedInOperatingActivities                   11497000000
# PurchaseOfDigitalAssets                                       1500000000
# InventoryWriteDown                                             140000000
# IncreaseDecreaseInOperatingLeaseVehicles                      2114000000
# ProceedsFromRepaymentsOfSecuredDebt                             -9000000
# EffectOfExchangeRateOnCashCashEquivalentsRestri...            -183000000
# ProceedsFromSalesOfDigitalAssets                               272000000
# ForeignCurrencyTransactionGainLossUnrealized                    55000000
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...             271000000
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...             707000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...           -1757000000
# PaymentsToAcquireOtherIndefiniteLivedIntangible...                     0
# NoncashInterestIncomeExpenseAndOtherOperatingAc...            -245000000
# IncreaseDecreaseInOtherNoncurrentAssets                       1291000000
# FinanceLeasePrincipalPayments                                  439000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...                     0
# PaymentsToAcquireInvestments                                   132000000
# GainLossOnDigitalAssets                                         27000000
# IncreaseDecreaseInAccountsPayableAndAccruedLiab...            4578000000
# PaymentsOfDebtIssuanceCosts                                      9000000
# ProceedsFromSaleMaturityAndCollectionsOfInvestm...                     0
# IncreaseDecreaseInContractWithCustomerLiability                793000000
# ProceedsFromMinorityShareholders                                 2000000
# GovernmentGrantReceipt                                           6000000
# IncreaseDecreaseInContractWithCustomerLiability...             186000000
# PaymentsToMinorityShareholders                                 161000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                           0
# IncreaseDecreaseInOtherNoncurrentLiabilities                   476000000
# PaymentsForBuyOutsOfNoncontrollingInterestsInSu...              10000000
# NetCashProvidedByUsedInInvestingActivities                   -7868000000
# NetCashProvidedByUsedInFinancingActivities                   -5203000000
#
#                                                      2021-12-31  \
# ProceedsFromIssuanceOfCommonStock                             0
# InterestPaidNet                                               0
# ProfitLoss                                                    0
# PaymentsToAcquirePropertyPlantAndEquipment                    0
# DepreciationAmortizationAndImpairment                         0
# IncreaseDecreaseInAccountsReceivable                          0
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcq...            0
# ProceedsFromIssuanceOfDebt                                    0
# IncomeTaxesPaid                                               0
# PaymentsForSolarEnergySystemsNetOfSales                       0
# ShareBasedCompensation                                        0
# IncreaseDecreaseInInventories                                 0
# RepaymentsOfConvertibleAndOtherDebt                           0
# NetCashProvidedByUsedInOperatingActivities                    0
# PurchaseOfDigitalAssets                                       0
# InventoryWriteDown                                            0
# IncreaseDecreaseInOperatingLeaseVehicles                      0
# ProceedsFromRepaymentsOfSecuredDebt                           0
# EffectOfExchangeRateOnCashCashEquivalentsRestri...            0
# ProceedsFromSalesOfDigitalAssets                              0
# ForeignCurrencyTransactionGainLossUnrealized                  0
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...            0
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...            0
# CashCashEquivalentsRestrictedCashAndRestrictedC...            0
# PaymentsToAcquireOtherIndefiniteLivedIntangible...            0
# NoncashInterestIncomeExpenseAndOtherOperatingAc...            0
# IncreaseDecreaseInOtherNoncurrentAssets                       0
# FinanceLeasePrincipalPayments                                 0
# CashCashEquivalentsRestrictedCashAndRestrictedC...  18144000000
# PaymentsToAcquireInvestments                                  0
# GainLossOnDigitalAssets                                       0
# IncreaseDecreaseInAccountsPayableAndAccruedLiab...            0
# PaymentsOfDebtIssuanceCosts                                   0
# ProceedsFromSaleMaturityAndCollectionsOfInvestm...            0
# IncreaseDecreaseInContractWithCustomerLiability               0
# ProceedsFromMinorityShareholders                              0
# GovernmentGrantReceipt                                        0
# IncreaseDecreaseInContractWithCustomerLiability...            0
# PaymentsToMinorityShareholders                                0
# PaymentsToAcquireBusinessesNetOfCashAcquired                  0
# IncreaseDecreaseInOtherNoncurrentLiabilities                  0
# PaymentsForBuyOutsOfNoncontrollingInterestsInSu...            0
# NetCashProvidedByUsedInInvestingActivities                    0
# NetCashProvidedByUsedInFinancingActivities                    0
#
#                                                    2022-01-01-2022-12-31  \
# ProceedsFromIssuanceOfCommonStock                                      0
# InterestPaidNet                                                152000000
# ProfitLoss                                                   12587000000
# PaymentsToAcquirePropertyPlantAndEquipment                    7158000000
# DepreciationAmortizationAndImpairment                         3747000000
# IncreaseDecreaseInAccountsReceivable                          1124000000
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcq...            2148000000
# ProceedsFromIssuanceOfDebt                                             0
# IncomeTaxesPaid                                               1203000000
# PaymentsForSolarEnergySystemsNetOfSales                          5000000
# ShareBasedCompensation                                        1560000000
# IncreaseDecreaseInInventories                                 6465000000
# RepaymentsOfConvertibleAndOtherDebt                           3364000000
# NetCashProvidedByUsedInOperatingActivities                   14724000000
# PurchaseOfDigitalAssets                                                0
# InventoryWriteDown                                             177000000
# IncreaseDecreaseInOperatingLeaseVehicles                      1570000000
# ProceedsFromRepaymentsOfSecuredDebt                                    0
# EffectOfExchangeRateOnCashCashEquivalentsRestri...            -444000000
# ProceedsFromSalesOfDigitalAssets                               936000000
# ForeignCurrencyTransactionGainLossUnrealized                   -81000000
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...            1417000000
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...             541000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...           -1220000000
# PaymentsToAcquireOtherIndefiniteLivedIntangible...               9000000
# NoncashInterestIncomeExpenseAndOtherOperatingAc...            -340000000
# IncreaseDecreaseInOtherNoncurrentAssets                       2551000000
# FinanceLeasePrincipalPayments                                  502000000
# CashCashEquivalentsRestrictedCashAndRestrictedC...                     0
# PaymentsToAcquireInvestments                                  5835000000
# GainLossOnDigitalAssets                                       -140000000
# IncreaseDecreaseInAccountsPayableAndAccruedLiab...            6029000000
# PaymentsOfDebtIssuanceCosts                                            0
# ProceedsFromSaleMaturityAndCollectionsOfInvestm...              22000000
# IncreaseDecreaseInContractWithCustomerLiability               1131000000
# ProceedsFromMinorityShareholders                                       0
# GovernmentGrantReceipt                                          76000000
# IncreaseDecreaseInContractWithCustomerLiability...             155000000
# PaymentsToMinorityShareholders                                 157000000
# PaymentsToAcquireBusinessesNetOfCashAcquired                           0
# IncreaseDecreaseInOtherNoncurrentLiabilities                  1904000000
# PaymentsForBuyOutsOfNoncontrollingInterestsInSu...              45000000
# NetCashProvidedByUsedInInvestingActivities                  -11973000000
# NetCashProvidedByUsedInFinancingActivities                   -3527000000
#
#                                                      2022-12-31
# ProceedsFromIssuanceOfCommonStock                             0
# InterestPaidNet                                               0
# ProfitLoss                                                    0
# PaymentsToAcquirePropertyPlantAndEquipment                    0
# DepreciationAmortizationAndImpairment                         0
# IncreaseDecreaseInAccountsReceivable                          0
# NoncashOrPartNoncashAcquisitionValueOfAssetsAcq...            0
# ProceedsFromIssuanceOfDebt                                    0
# IncomeTaxesPaid                                               0
# PaymentsForSolarEnergySystemsNetOfSales                       0
# ShareBasedCompensation                                        0
# IncreaseDecreaseInInventories                                 0
# RepaymentsOfConvertibleAndOtherDebt                           0
# NetCashProvidedByUsedInOperatingActivities                    0
# PurchaseOfDigitalAssets                                       0
# InventoryWriteDown                                            0
# IncreaseDecreaseInOperatingLeaseVehicles                      0
# ProceedsFromRepaymentsOfSecuredDebt                           0
# EffectOfExchangeRateOnCashCashEquivalentsRestri...            0
# ProceedsFromSalesOfDigitalAssets                              0
# ForeignCurrencyTransactionGainLossUnrealized                  0
# IncreaseDecreaseInPrepaidDeferredExpenseAndOthe...            0
# ProceedsFromIssuanceOfSharesUnderIncentiveAndSh...            0
# CashCashEquivalentsRestrictedCashAndRestrictedC...            0
# PaymentsToAcquireOtherIndefiniteLivedIntangible...            0
# NoncashInterestIncomeExpenseAndOtherOperatingAc...            0
# IncreaseDecreaseInOtherNoncurrentAssets                       0
# FinanceLeasePrincipalPayments                                 0
# CashCashEquivalentsRestrictedCashAndRestrictedC...  16924000000
# PaymentsToAcquireInvestments                                  0
# GainLossOnDigitalAssets                                       0
# IncreaseDecreaseInAccountsPayableAndAccruedLiab...            0
# PaymentsOfDebtIssuanceCosts                                   0
# ProceedsFromSaleMaturityAndCollectionsOfInvestm...            0
# IncreaseDecreaseInContractWithCustomerLiability               0
# ProceedsFromMinorityShareholders                              0
# GovernmentGrantReceipt                                        0
# IncreaseDecreaseInContractWithCustomerLiability...            0
# PaymentsToMinorityShareholders                                0
# PaymentsToAcquireBusinessesNetOfCashAcquired                  0
# IncreaseDecreaseInOtherNoncurrentLiabilities                  0
# PaymentsForBuyOutsOfNoncontrollingInterestsInSu...            0
# NetCashProvidedByUsedInInvestingActivities                    0
# NetCashProvidedByUsedInFinancingActivities                    0
